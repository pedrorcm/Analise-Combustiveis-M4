# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Tratamento

# %%
csv = pd.read_csv('dados/precos-gasolina-etanol-07.csv', delimiter=';')
comb_jul = pd.DataFrame(csv)
comb_jul.head(1)
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             ES  COLATINA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
#
#              Nome da Rua Numero Rua Complemento Bairro        Cep  \
# 0  PRACA FIDELIS FERRARI         35         NaN   LACE  29703-030
#
#               Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0  GASOLINA ADITIVADA     01/07/2022           7,48              NaN
#
#   Unidade de Medida       Bandeira
# 0        R$ / litro  VIBRA ENERGIA

# %%
csv = pd.read_csv('dados/precos-gasolina-etanol-08.csv', delimiter=';')
comb_ago = pd.DataFrame(csv)
comb_ago.head(1)
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio                      Revenda  \
# 0             NE             AL  ARAPIRACA  AUTO POSTO M M GARROTE LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   08.738.994/0001-50  RODOVIA AL-220       5848    KM    96  BOM SUCESSO
#
#          Cep Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0  57309-035  ETANOL     01/08/2022           4,79              NaN
#
#   Unidade de Medida       Bandeira
# 0        R$ / litro  VIBRA ENERGIA

# %%
conjunto_dados = pd.concat([comb_jul, comb_ago])
conjunto_dados.head(1)
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             ES  COLATINA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
#
#              Nome da Rua Numero Rua Complemento Bairro        Cep  \
# 0  PRACA FIDELIS FERRARI         35         NaN   LACE  29703-030
#
#               Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0  GASOLINA ADITIVADA     01/07/2022           7,48              NaN
#
#   Unidade de Medida       Bandeira
# 0        R$ / litro  VIBRA ENERGIA

# %%
conjunto_dados.reset_index(0,drop=True,inplace=True)

# %%
((conjunto_dados.isnull().sum() / conjunto_dados.shape[0]) * 100).sort_values(ascending=False)
# Out:
# Valor de Compra      100.000000
# Complemento           78.707461
# Bairro                 0.323960
# Numero Rua             0.055828
# Regiao - Sigla         0.000000
# Estado - Sigla         0.000000
# Municipio              0.000000
# Revenda                0.000000
# CNPJ da Revenda        0.000000
# Nome da Rua            0.000000
# Cep                    0.000000
# Produto                0.000000
# Data da Coleta         0.000000
# Valor de Venda         0.000000
# Unidade de Medida      0.000000
# Bandeira               0.000000
# dtype: float64

# %%
conjunto_dados.drop('Valor de Compra', axis=1, inplace=True)

# %%
conjunto_dados['Valor de Venda'] = conjunto_dados['Valor de Venda'].apply(lambda y: float(str(y.replace(',','.'))))

# %%
conjunto_dados.Complemento.fillna('0', inplace=True)

# %%
conjunto_dados.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             ES  COLATINA
# 1             SE             ES  COLATINA
# 2             SE             ES  COLATINA
# 3             SE             ES  COLATINA
# 4             CO             GO   GOIANIA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
# 1  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
# 2                                 POSTO MOTOCAP LTDA   04.814.652/0001-10
# 3                                 POSTO MOTOCAP LTDA   04.814.652/0001-10
# 4                       JUSTINIANO & JUSTINIANO LTDA   04.489.287/0001-16
#
#                     Nome da Rua Numero Rua         Complemento  \
# 0         PRACA FIDELIS FERRARI         35                   0
# 1         PRACA FIDELIS FERRARI         35                   0
# 2       PRACA ALMIRANTE BARROSO         52             LETRA A
# ...

# %%
conjunto_dados['Data da Coleta'] = pd.to_datetime(conjunto_dados['Data da Coleta'],format='%d/%m/%Y')
conjunto_dados.head(1)
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             ES  COLATINA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
#
#              Nome da Rua Numero Rua Complemento Bairro        Cep  \
# 0  PRACA FIDELIS FERRARI         35           0   LACE  29703-030
#
#               Produto Data da Coleta  Valor de Venda Unidade de Medida  \
# 0  GASOLINA ADITIVADA     2022-07-01            7.48        R$ / litro
#
#         Bandeira
# 0  VIBRA ENERGIA

# %%
conjunto_dados.loc[(conjunto_dados['Data da Coleta'] > '2022-07-11') & (conjunto_dados['Data da Coleta'] < '2022-07-15')]
# Out:
#       Regiao - Sigla Estado - Sigla      Municipio  \
# 18585              S             RS   PORTO ALEGRE
# 18586              S             RS   PORTO ALEGRE
# 18587              N             AC     RIO BRANCO
# 18588              N             AC     RIO BRANCO
# 18589              N             AC     RIO BRANCO
# ...              ...            ...            ...
# 28444             NE             BA          IRECE
# 28445             NE             PE         RECIFE
# 28446             NE             PE         RECIFE
# 28447              S             SC  FLORIANOPOLIS
# 28448              S             SC  FLORIANOPOLIS
#
#                                                  Revenda      CNPJ da Revenda  \
# 18585                  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14
# 18586                  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14
# 18587                           CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# ...

# %%
conjunto_dados.dtypes
# Out:
# Regiao - Sigla               object
# Estado - Sigla               object
# Municipio                    object
# Revenda                      object
# CNPJ da Revenda              object
# Nome da Rua                  object
# Numero Rua                   object
# Complemento                  object
# Bairro                       object
# Cep                          object
# Produto                      object
# Data da Coleta       datetime64[ns]
# Valor de Venda              float64
# Unidade de Medida            object
# Bandeira                     object
# dtype: object

# %%
#conjunto_dados['Data da Coleta'] = conjunto_dados['Data da Coleta'].dt.strftime('%d-%m-%Y')
#conjunto_dados.head(1)

# %%
conjunto_dados['Data da Coleta'][0]
# Out:
# Timestamp('2022-07-01 00:00:00')

# %% [markdown]
# ## Trabalhando nos dados

# %%
# 7. Qual a região que possui o maior valor médio da gasolina?

# Criando um recorte do DF original onde temos apenas os registros da Gasolina
df_gas = conjunto_dados.query('Produto == "GASOLINA"').copy()
df_gas
# Out:
#        Regiao - Sigla Estado - Sigla             Municipio  \
# 1                  SE             ES              COLATINA
# 3                  SE             ES              COLATINA
# 6                  CO             GO               GOIANIA
# 9                  CO             GO               GOIANIA
# 12                 NE             PI              TERESINA
# ...               ...            ...                   ...
# 127164             NE             BA  VITORIA DA CONQUISTA
# 127167             NE             BA                 IRECE
# 127169             NE             PE                RECIFE
# 127172             CO             DF              BRASILIA
# 127174             SE             MG               JANAUBA
#
#                                                   Revenda  \
# 1       SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...
# 3                                      POSTO MOTOCAP LTDA
# 6                            JUSTINIANO & JUSTINIANO LTDA
# ...

# %%
df_gas.groupby(['Regiao - Sigla', 'Produto'])[['Valor de Venda']].mean().sort_values(by='Valor de Venda', ascending=False)
# Out:
#                          Valor de Venda
# Regiao - Sigla Produto
# N              GASOLINA        5.972082
# NE             GASOLINA        5.955809
# S              GASOLINA        5.641161
# SE             GASOLINA        5.615655
# CO             GASOLINA        5.581603

# %%
# 8. Qual a região que possui o menor valor médio do etanol?

# Criando um recorte do DF original onde temos apenas os registros do Etanol
df_et = conjunto_dados.loc[(conjunto_dados['Produto'] == 'etanol'.upper()), :]

# %%
df_et.groupby(['Regiao - Sigla', 'Produto'])[['Valor de Venda']].mean().sort_values(by='Valor de Venda', ascending=True)
# Out:
#                         Valor de Venda
# Regiao - Sigla Produto
# CO             ETANOL         4.107305
# SE             ETANOL         4.149964
# S              ETANOL         4.842372
# NE             ETANOL         5.246069
# N              ETANOL         5.340633
